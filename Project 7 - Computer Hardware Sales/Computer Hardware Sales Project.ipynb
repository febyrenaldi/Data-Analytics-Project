# %%
SELECT * FROM 'Computer Hardware Sales.csv' AS c
# Out:
#                           Date     Month  ...  Order Price Order Profit
# 0    2023-07-10 00:00:00+00:00      July  ...       193200        25200
# 1    2023-05-31 00:00:00+00:00       May  ...       193200        25200
# 2    2022-05-17 00:00:00+00:00       May  ...        96600        12600
# 3    2022-12-19 00:00:00+00:00  December  ...       241500        31500
# 4    2023-03-21 00:00:00+00:00     March  ...        48300         6300
# ...                        ...       ...  ...          ...          ...
# 9207 2023-08-26 00:00:00+00:00    August  ...     35275100      4601100
# 9208 2022-07-18 00:00:00+00:00      July  ...     45353700      5915700
# 9209 2022-06-12 00:00:00+00:00      June  ...     40314400      5258400
# 9210 2023-02-27 00:00:00+00:00  February  ...     45353700      5915700
# 9211 2023-06-22 00:00:00+00:00      June  ...     55432300      7230300
#
# [9212 rows x 18 columns]
